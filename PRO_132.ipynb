# %% [markdown]
# <a href="https://colab.research.google.com/github/Xander50/PRO-132/blob/main/PRO_132.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Xander50/PRO-131
# Out:
# Cloning into 'PRO-131'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 9 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (9/9), 12.50 KiB | 1.04 MiB/s, done.

# %%
import pandas as pd
df=pd.read_csv('/content/PRO-131/star_with_gravity.csv')

# %%
df
# Out:
#      Unnamed: 0               Star_name     Distance       Mass     Radius  \
# 0             0                     Sun  0.000015813   1.000000   1.000000
# 1             1                  Sirius          8.6   2.100000   1.710000
# 2             2                 Canopus          310  15.000000  71.000000
# 3             3          Alpha Centauri          4.4   1.100000   1.200000
# 4             4                Arcturus           37   1.100000  26.000000
# ..          ...                     ...          ...        ...        ...
# 248         248  2MASSI J2356547-155310           74   0.076367   0.112012
# 249         249          WISE 0410+1502           20   0.005728   0.120233
# 250         250         WISE 0458+6434A         35.9   0.014319   0.431605
# 251         251         WISE 0458+6434B         35.9   0.009546   0.390499
# 252         252          WISE 1405+5534         25.3   0.028638   0.088376
#
#           Gravity
# 0    2.742692e+02
# 1    1.969718e+02
# ...

# %%
mass=df["Mass"].to_list()
radius=df["Radius"].to_list()
gravity=df["Gravity"].to_list()

# %%
mass.sort()
radius.sort()
gravity.sort()
import matplotlib.pyplot as plt
plt.plot(radius,mass)
plt.title("radius and mass of the star")
plt.xlabel("Radius")
plt.ylabel("Mass")
plt.show()

# %%
plt.plot(gravity,mass)
plt.title("gravity and mass of the star")
plt.ylabel("Gravity")
plt.xlabel("Mass")
plt.show()

# %%
plt.plot(gravity,radius)
plt.title("gravity and radius of the star")
plt.ylabel("Gravity")
plt.xlabel("Radius")
plt.show()
